# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika0501/Python_practice/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
#import pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#1.create Dataframe
df=pd.DataFrame([11,22,33],columns=["Col_Name"])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    "Name":["madhav","lalita","monika","Honey"],
    "age":[14,15,16,17],
    "salary":[9000,4000,5000,3000]

}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  age  salary
# 0  madhav   14    9000
# 1  lalita   15    4000
# 2  monika   16    5000
# 3   Honey   17    3000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#2.Basic Dataframe Understanding

# %%
df.head(2) #top rows
# Out:
#      Name  age  salary
# 0  madhav   14    9000
# 1  lalita   15    4000

# %%
df.tail(2) #Last rows
# Out:
#      Name  age  salary
# 2  monika   16    5000
# 3   Honey   17    3000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'age', 'salary'], dtype='object')

# %%
df.rename(columns={"salary":"Monthly Salary"},inplace=True)

# %%
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   age             4 non-null      int64
#  2   Monthly Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              age  Monthly Salary
# count   4.000000         4.00000
# mean   15.500000      5250.00000
# std     1.290994      2629.95564
# min    14.000000      3000.00000
# 25%    14.750000      3750.00000
# 50%    15.500000      4500.00000
# 75%    16.250000      6000.00000
# max    17.000000      9000.00000

# %%
#Save and load data from csv

# %%
df.to_csv("Test_data.csv") #export data frame

# %%
load_df=pd.read_csv("Test_data.csv") #import dataframe
load_df
# Out:
#    Unnamed: 0    Name  age  Monthly Salary
# 0           0  madhav   14            9000
# 1           1  lalita   15            4000
# 2           2  monika   16            5000
# 3           3   Honey   17            3000

# %%
#Rows and columns-selection
#select column
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df[["Name"]] #if i want single column
# Out:
#      Name
# 0  madhav
# 1  lalita
# 2  monika
# 3   Honey

# %%
df[["Name","Monthly Salary"]]
# Out:
#      Name  Monthly Salary
# 0  madhav            9000
# 1  lalita            4000
# 2  monika            5000
# 3   Honey            3000

# %%
#select rows
#loc-index name based singal row
df.loc[df.Name=="madhav"]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000

# %%
df.loc[(df.Name=="madhav") & (df['Monthly Salary']>=5000)] #selecting multiple rows using AND
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000

# %%
df.loc[0:2]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000

# %%
#iloc-index value based
df.iloc[0]
# Out:
# Name              madhav
# age                   14
# Monthly Salary      9000
# Name: 0, dtype: object

# %%
df.iloc[0:2] # [start:stop:step]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000

# %%
#filter dataframe
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000
