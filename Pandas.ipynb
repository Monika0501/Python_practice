# %% [markdown]
# <a href="https://colab.research.google.com/github/Monika0501/Python_practice/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
#import pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#1.create Dataframe
df=pd.DataFrame([11,22,33],columns=["Col_Name"])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = {
    "Name":["madhav","lalita","monika","Honey"],
    "age":[14,15,16,17],
    "salary":[9000,4000,5000,3000]

}

# %%
df=pd.DataFrame(data)
print(df)
# Out:
#      Name  age  salary
# 0  madhav   14    9000
# 1  lalita   15    4000
# 2  monika   16    5000
# 3   Honey   17    3000

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
#2.Basic Dataframe Understanding

# %%
df.head(2) #top rows
# Out:
#      Name  age  salary
# 0  madhav   14    9000
# 1  lalita   15    4000

# %%
df.tail(2) #Last rows
# Out:
#      Name  age  salary
# 2  monika   16    5000
# 3   Honey   17    3000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'age', 'salary'], dtype='object')

# %%
df.rename(columns={"salary":"Monthly Salary"},inplace=True)

# %%
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   age             4 non-null      int64
#  2   Monthly Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df.describe()
# Out:
#              age  Monthly Salary
# count   4.000000         4.00000
# mean   15.500000      5250.00000
# std     1.290994      2629.95564
# min    14.000000      3000.00000
# 25%    14.750000      3750.00000
# 50%    15.500000      4500.00000
# 75%    16.250000      6000.00000
# max    17.000000      9000.00000

# %%
#Save and load data from csv

# %%
df.to_csv("Test_data.csv") #export data frame

# %%
load_df=pd.read_csv("Test_data.csv") #import dataframe
load_df
# Out:
#    Unnamed: 0    Name  age  Monthly Salary
# 0           0  madhav   14            9000
# 1           1  lalita   15            4000
# 2           2  monika   16            5000
# 3           3   Honey   17            3000

# %%
#Rows and columns-selection
#select column
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df[["Name"]] #if i want single column
# Out:
#      Name
# 0  madhav
# 1  lalita
# 2  monika
# 3   Honey

# %%
df[["Name","Monthly Salary"]]
# Out:
#      Name  Monthly Salary
# 0  madhav            9000
# 1  lalita            4000
# 2  monika            5000
# 3   Honey            3000

# %%
#select rows
#loc-index name based singal row
df.loc[df.Name=="madhav"]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000

# %%
df.loc[(df.Name=="madhav") & (df['Monthly Salary']>=5000)] #selecting multiple rows using AND
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000

# %%
df.loc[0:2]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000

# %%
#iloc-index value based
df.iloc[0]
# Out:
# Name              madhav
# age                   14
# Monthly Salary      9000
# Name: 0, dtype: object

# %%
df.iloc[0:2] # [start:stop:step]
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000

# %%
#filter dataframe
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df["age"]>15
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# Name: age, dtype: bool

# %%
df_age_filter=df[df["age"]>=15]

# %%
df_age_filter
# Out:
#      Name  age  Monthly Salary
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
df[(df["age"]>=15) & (df["Monthly Salary"]>=5000)]
# Out:
#      Name  age  Monthly Salary
# 2  monika   16            5000

# %%
df.where(df["age"]>=15, other="Not Eligible")
# Out:
#            Name           age Monthly Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1        lalita            15           4000
# 2        monika            16           5000
# 3         Honey            17           3000

# %%
#Rows and columns- Operations(add,update,delete)

# %%
df
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14            9000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000

# %%
#add new column
df["Team"]=["CEO","DA","CTO","BA"]
df
# Out:
#      Name  age  Monthly Salary Team
# 0  madhav   14            9000  CEO
# 1  lalita   15            4000   DA
# 2  monika   16            5000  CTO
# 3   Honey   17            3000   BA

# %%
df["Bonus"]=df["Monthly Salary"]*0.2
df
# Out:
#      Name  age  Monthly Salary Team   Bonus
# 0  madhav   14            9000  CEO  1800.0
# 1  lalita   15            4000   DA   800.0
# 2  monika   16            5000  CTO  1000.0
# 3   Honey   17            3000   BA   600.0

# %%
#add new row
df.loc[len(df)]=["ABC",21,2100,"IT",1000]
df
# Out:
#      Name  age  Monthly Salary Team   Bonus
# 0  madhav   14            9000  CEO  1800.0
# 1  lalita   15            4000   DA   800.0
# 2  monika   16            5000  CTO  1000.0
# 3   Honey   17            3000   BA   600.0
# 4     ABC   21            2100   IT  1000.0

# %%
len(df)
# Out:
# 5

# %%
#update value
df.loc[0,"Monthly Salary"]=95000 #index name used
df
# Out:
#      Name  age  Monthly Salary Team   Bonus
# 0  madhav   14           95000  CEO  1800.0
# 1  lalita   15            4000   DA   800.0
# 2  monika   16            5000  CTO  1000.0
# 3   Honey   17            3000   BA   600.0
# 4     ABC   21            2100   IT  1000.0

# %%
#update value - using column value
df.loc[df.Name=="madhav","Monthly Salary"]=100000
df
# Out:
#      Name  age  Monthly Salary Team   Bonus
# 0  madhav   14          100000  CEO  1800.0
# 1  lalita   15            4000   DA   800.0
# 2  monika   16            5000  CTO  1000.0
# 3   Honey   17            3000   BA   600.0
# 4     ABC   21            2100   IT  1000.0

# %%
#delete value-row and column values
df.drop(df[df.Name=="ABC"].index) #drop row,axis=0
# Out:
#      Name  age  Monthly Salary Team   Bonus
# 0  madhav   14          100000  CEO  1800.0
# 1  lalita   15            4000   DA   800.0
# 2  monika   16            5000  CTO  1000.0
# 3   Honey   17            3000   BA   600.0

# %%
df.drop(1, axis=0) #index name
# Out:
#      Name  age  Salary Team
# 0  madhav   14  100000  CEO
# 2  monika   16    5000  CTO
# 3   Honey   17    3000   BA
# 4     ABC   21    2100   IT

# %%
df.drop('Bonus',axis=1, inplace=True, errors='ignore')
df
# Out:
#      Name  age  Salary Team
# 0  madhav   14  100000  CEO
# 2  monika   16    5000  CTO
# 1  lalita   15    4000   DA
# 3   Honey   17    3000   BA
# 4     ABC   21    2100   IT

# %%
#df.drop(['Team', 'Bonus'], axis=1, errors='ignore')  #delete multiple colums
# Out:
#      Name  age  Monthly Salary
# 0  madhav   14          100000
# 1  lalita   15            4000
# 2  monika   16            5000
# 3   Honey   17            3000
# 4     ABC   21            2100

# %%
df
# Out:
#      Name  age  Monthly Salary Team
# 0  madhav   14          100000  CEO
# 1  lalita   15            4000   DA
# 2  monika   16            5000  CTO
# 3   Honey   17            3000   BA
# 4     ABC   21            2100   IT

# %%
df.rename(columns={'Monthly Salary':'Salary'}, inplace=True)
df
# Out:
#      Name  age  Salary Team
# 0  madhav   14  100000  CEO
# 1  lalita   15    4000   DA
# 2  monika   16    5000  CTO
# 3   Honey   17    3000   BA
# 4     ABC   21    2100   IT

# %%
#sort value
df.sort_values('Salary') #ascending order by default
# Out:
#      Name  age  Salary Team
# 0  madhav   14  100000  CEO
# 2  monika   16    5000  CTO
# 1  lalita   15    4000   DA
# 3   Honey   17    3000   BA
# 4     ABC   21    2100   IT

# %%
df.sort_values('Salary', ascending=False) #descending order
df
# Out:
#      Name  age  Salary Team
# 0  madhav   14  100000  CEO
# 2  monika   16    5000  CTO
# 1  lalita   15    4000   DA
# 3   Honey   17    3000   BA
# 4     ABC   21    2100   IT

# %%
#working with date dat type

# %%
df['DOJ']=['2024-01-01','2024-01-15','2024-03-28','2024-03-03','2024-01-01']
df
# Out:
#      Name  age  Salary Team         DOJ
# 0  madhav   14  100000  CEO  2024-01-01
# 2  monika   16    5000  CTO  2024-01-15
# 1  lalita   15    4000   DA  2024-03-28
# 3   Honey   17    3000   BA  2024-03-03
# 4     ABC   21    2100   IT  2024-01-01

# %%
df['DOJ'].dtype
# Out:
# dtype('O')

# %%
df['DOJ']=pd.to_datetime(df['DOJ'])
df['DOJ'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df1=df

# %%
df1
# Out:
#      Name  age  Salary Team        DOJ
# 0  madhav   14  100000  CEO 2024-01-01
# 2  monika   16    5000  CTO 2024-01-15
# 1  lalita   15    4000   DA 2024-03-28
# 3   Honey   17    3000   BA 2024-03-03
# 4     ABC   21    2100   IT 2024-01-01

# %%
df1['DOJ2']=['01-01-2025','15-01-2025','28-03-2025','03-03-2025','01-01-2025']
df1
# Out:
#      Name  age  Salary Team        DOJ        DOJ2
# 0  madhav   14  100000  CEO 2024-01-01  01-01-2025
# 2  monika   16    5000  CTO 2024-01-15  15-01-2025
# 1  lalita   15    4000   DA 2024-03-28  28-03-2025
# 3   Honey   17    3000   BA 2024-03-03  03-03-2025
# 4     ABC   21    2100   IT 2024-01-01  01-01-2025

# %%
df1['DOJ2'].dtypes
# Out:
# dtype('O')

# %%
df1['DOJ2']=pd.to_datetime(df['DOJ2'], format='%d-%m-%Y')

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df=df.drop('DOJ2',axis=1)

# %%
df
# Out:
#      Name  age  Salary Team        DOJ
# 0  madhav   14  100000  CEO 2024-01-01
# 2  monika   16    5000  CTO 2024-01-15
# 1  lalita   15    4000   DA 2024-03-28
# 3   Honey   17    3000   BA 2024-03-03
# 4     ABC   21    2100   IT 2024-01-01

# %%
#extract year, month,week day

df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Monday
# 2      Monday
# 1    Thursday
# 3      Sunday
# 4      Monday
# Name: DOJ, dtype: object

# %%
df['Month']=df['DOJ'].dt.month

# %%
df
# Out:
#      Name  age  Salary Team        DOJ  Month
# 0  madhav   14  100000  CEO 2024-01-01      1
# 2  monika   16    5000  CTO 2024-01-15      1
# 1  lalita   15    4000   DA 2024-03-28      3
# 3   Honey   17    3000   BA 2024-03-03      3
# 4     ABC   21    2100   IT 2024-01-01      1

# %%
df['DOJ']+pd.Timedelta(days=90)
# Out:
# 0   2024-03-31
# 2   2024-04-14
# 1   2024-06-26
# 3   2024-06-01
# 4   2024-03-31
# Name: DOJ, dtype: datetime64[ns]

# %%
df
# Out:
#      Name  age  Salary Team        DOJ  Month
# 0  madhav   14  100000  CEO 2024-01-01      1
# 2  monika   16    5000  CTO 2024-01-15      1
# 1  lalita   15    4000   DA 2024-03-28      3
# 3   Honey   17    3000   BA 2024-03-03      3
# 4     ABC   21    2100   IT 2024-01-01      1

# %% [markdown]
# #Handling missing values

# %%
df.isnull()
# Out:
#     Name    age  Salary   Team    DOJ  Month
# 0  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 3  False  False   False  False  False  False
# 4  False  False   False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=="Honey","Salary"]=np.nan

# %%
df
# Out:
#      Name  age    Salary Team        DOJ  Month
# 0  madhav   14  100000.0  CEO 2024-01-01      1
# 2  monika   16    5000.0  CTO 2024-01-15      1
# 1  lalita   15    4000.0   DA 2024-03-28      3
# 3   Honey   17       NaN   BA 2024-03-03      3
# 4     ABC   21    2100.0   IT 2024-01-01      1

# %%
df.isnull()
# Out:
#     Name    age  Salary   Team    DOJ  Month
# 0  False  False   False  False  False  False
# 2  False  False   False  False  False  False
# 1  False  False   False  False  False  False
# 3  False  False    True  False  False  False
# 4  False  False   False  False  False  False

# %%
df.isnull().sum()
# Out:
# Name      0
# age       0
# Salary    1
# Team      0
# DOJ       0
# Month     0
# dtype: int64

# %%
df.fillna(0)
# Out:
#      Name  age    Salary Team        DOJ  Month
# 0  madhav   14  100000.0  CEO 2024-01-01      1
# 2  monika   16    5000.0  CTO 2024-01-15      1
# 1  lalita   15    4000.0   DA 2024-03-28      3
# 3   Honey   17       0.0   BA 2024-03-03      3
# 4     ABC   21    2100.0   IT 2024-01-01      1

# %%
#Agregation and group by
df["Team"].value_counts()
# Out:
# Team
# CEO    1
# CTO    1
# DA     1
# BA     1
# IT     1
# Name: count, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# Month
# 1    3
# 3    2
# Name: count, dtype: int64

# %%
df[df['Month']==1].value_counts()
# Out:
# Name    age  Salary    Team  DOJ         Month
# ABC     21   2100.0    IT    2024-01-01  1        1
# madhav  14   100000.0  CEO   2024-01-01  1        1
# monika  16   5000.0    CTO   2024-01-15  1        1
# Name: count, dtype: int64

# %%
df.groupby('Month')['Salary'].sum() #aggregation based on group by
# Out:
# Month
# 1    107100.0
# 3      4000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Month').agg({'Salary':'mean','Name':'count'})
# Out:
#         Salary  Name
# Month
# 1      35700.0     3
# 3       4000.0     2

# %% [markdown]
# ###concatenate and merge dataframe(Joins)

# %%
df1=pd.DataFrame({'ID':[1,2,3],'Name':['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2=pd.DataFrame({'ID':[1,2,2,4],'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df1,df2],axis=0) #vertical/row level/top on top
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
pd.concat([df1,df2],axis=1) #Horizontal/column level/side on side
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
#merge=join
pd.merge(df1,df2,how='inner',on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1,df2,how='right',on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
# 3   4  NaN     79

# %%
pd.merge(df1,df2,how='left',on='ID') #we cna use left,right,inner,outer
# Out:
#    ID Name  Score
# 0   1    A   88.0
# 1   2    B   96.0
# 2   2    B   77.0
# 3   3    C    NaN

# %%
pd.merge(df1,df2,how="inner",left_on='ID',right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77
